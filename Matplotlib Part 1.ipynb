# %% [markdown]
# <a href="https://colab.research.google.com/github/LaetitiaVerel/Odyssey-Quests/blob/master/Deviens%20un%20%22artiste%22%20avec%20Matplotlib%20Partie%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mission 1
#
# Modifie le code ci-dessous dans une autre cellule code pour que :
# - La courbe du deuxième graphique se retrouve dans le premier graphique (donc 3 courbes dans le premier graphique )
# - La courbe orange se retrouve dans le deuxième graphique
# - Les labels soient écrit à droite et non pas à gauche

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))               
nse2 = np.random.randn(len(t))               

s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('coherence')

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))               
nse2 = np.random.randn(len(t))               

s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1, s2 and coherence')
axs[0].yaxis.set_label_position('right')
axs[0].grid(True)

cxy, f = axs[0].cohere(s1, s2, 256, 1. / dt)
axs[1].plot( t, s2)
axs[1].set_xlim(0, 2)
axs[1].set_xlabel('time')
axs[1].grid(True)
axs[1].set_ylabel('s2 ')
axs[1].yaxis.set_label_position('right')

fig.tight_layout()
plt.show()

# %% [markdown]
# # Mission 2
#
# Commente le code ci-dessous ligne par ligne pour l'expliquer à un collègue

# %%
import matplotlib.pyplot as plt # Importer la bibliothèque Matplotlib
import numpy as np # Importer la bibliothèque Numpy
x = np.linspace(0, 10) # x est l'abscisse constitué d'un array (Numpy) de 1 à 10, contenant 50 valeurs
with plt.style.context('Solarize_Light2'): # Type de graphique
    plt.plot(x, np.sin(x) + x + np.random.randn(50)) # Calculs de l'abscisse pour chaque ligne plt.plot(x,y)
    plt.plot(x, np.sin(x) + 2 * x + np.random.randn(50)) # Avec x = np.linspace(0, 10) et y = np.sin(x) + x + np.random.randn(50)
    plt.plot(x, np.sin(x) + 3 * x + np.random.randn(50))
    plt.plot(x, np.sin(x) + 4 + np.random.randn(50))
    plt.plot(x, np.sin(x) + 5 * x + np.random.randn(50))
    plt.plot(x, np.sin(x) + 6 * x + np.random.randn(50))
    plt.plot(x, np.sin(x) + 7 * x + np.random.randn(50))
    plt.plot(x, np.sin(x) + 8 * x + np.random.randn(50))
    plt.title('8 Random Lines - Line') # Titre du graphique
    plt.xlabel('x label', fontsize=14) # Légende de l'axe des abscisses et taille de la police
    plt.ylabel('y label', fontsize=14) # Légende de l'axe des ordonnées et taille de la police

plt.show() # Afficher le graphique
