# %% [markdown]
# <a href="https://colab.research.google.com/github/LaetitiaVerel/Odyssey-Quests/blob/master/Matplotlib%20Part%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mission 1
#
# Modifie le code ci-dessous de manière à ce que :
#
# - La taille de la barre de Bernard s'arrête à 11,5, celle de Martine à 8
# - La barre de Jessica doit commencer à 2
# - Attribue une couleur différente pour chaque barre

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

people = ('Bernard', 'Hector', 'Jessica', 'Jacques', 'Martine')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis() 
ax.set_xlabel('Avancement')
ax.set_title("Quel est ton taux d'avancement sur les quêtes ?")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

people = ('Bernard', 'Hector', 'Jessica', 'Jacques', 'Martine')
y_pos = np.arange(len(people))
performance = [11.5, 10, 6, 9, 8]
left=(0,0,2,0,0)
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color=['darkgreen', 'seagreen', 'mediumaquamarine', 'mediumturquoise', 'deepskyblue'], ecolor='black', left = left)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis() 
ax.set_xlabel('Avancement')
ax.set_title("Quel est ton taux d'avancement sur les quêtes ?")

plt.show()

# %% [markdown]
# # Mission 2
#
# Modifie le code ci-dessous dans une nouvelle cellule pour que :
# - Les valeurs pour hommes soient à droite et celles pour femmes à gauche
# - Modifier la couleur des colonnes
# - Diminuer l'épaisseur des paires de baton

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels)) 
width = 0.35  

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3), 
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels)) 
width = 0.20  

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, women_means, width, label='Women', color = 'pink')
rects2 = ax.bar(x + width/2, men_means, width, label='Men', color= 'cornflowerblue')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3), 
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# # Mission 3
#
# Commente le code ci-dessous pour l'expliquer à un collège

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt # Importer les bibliothèques Matplotlib et Numpy

np.random.seed(19680801) # Fonction seed() 

mu = 100  # Définir les paramètres de x
sigma = 15  
x = mu + sigma * np.random.randn(437)

num_bins = 50 # Nombre de barres dans l'histogramme

fig, ax = plt.subplots() # Créer la variable du graphique

n, bins, patches = ax.hist(x, num_bins, density=1) # Création de l'histogramme

y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * # Définir les paramètres de y
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--') # Définir les paramètres de la courbe de densité
ax.set_xlabel('Smarts') # Définir les titres des variables et de l'histogramme
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

fig.tight_layout() # Afficher le graphique
plt.show()
