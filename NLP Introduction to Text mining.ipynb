# %% [markdown]
# <a href="https://colab.research.google.com/github/LaetitiaVerel/Odyssey-Quests/blob/master/NLP%20Introduction%20to%20Text%20mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.
# Installe NLTK et télécharge les fonctions dont tu auras besoin (au fur et à mesure si nécessaire).
#
# 2.
# Récupère le texte d'un article de presse de ton choix sur internet (en anglais). Affecte-le à une variable.
#
# 3.
# Transforme ton texte en tokens de phrases, puis en tokens de mots.
#
# 4.
# Compte la fréquence d'apparition de chaque mot et réalise un graphique qui représente les 20 mots les plus présents dans ton texte.
#
# 5.
# Enlève les stop words et regarde à nouveau quels sont les mots les plus présents. Là encore, réalise un graphique.
#
# 6.
# Utilise un stemmer et/ou un lemmatizer pour rendre le corpus de mots encore plus pertinent, et réalise un dernier graphique.
#
# 7.
# Sélectionne le preprocessing le plus pertinent et réalise un wordcloud mettant en avant les mots les plus utilisés dans ton texte.
#
# 8.
# Partage le lien vers ton notebook en guise de solution au challenge.

# %%
import nltk
import nltk
nltk.download('punkt')
import numpy as np
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.probability import ConditionalFreqDist 
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import RegexpTokenizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
Tech_news =  "Snapchat will no longer promote President Donald Trump's account on its platform in the wake of his controversial comments on ongoing protests across the US, the company announced Wednesday. 'We are not currently promoting the President's content on Snapchat's Discover platform. We will not amplify voices who incite racial violence and injustice by giving them free promotion on Discover', Rachel Racusen, a spokesperson for Snap, Snapchat's parent company, said in a statement Wednesday."

# %%
sent_tk = sent_tokenize(Tech_news)
sent_tk
# Out:
# ["Snapchat will no longer promote President Donald Trump's account on its platform in the wake of his controversial comments on ongoing protests across the US, the company announced Wednesday.",
#  "'We are not currently promoting the President's content on Snapchat's Discover platform.",
#  "We will not amplify voices who incite racial violence and injustice by giving them free promotion on Discover', Rachel Racusen, a spokesperson for Snap, Snapchat's parent company, said in a statement Wednesday."]

# %%
word_tk = word_tokenize(Tech_news)
word_tk
# Out:
# ['Snapchat',
#  'will',
#  'no',
#  'longer',
#  'promote',
#  'President',
#  'Donald',
#  'Trump',
#  "'s",
#  'account',
#  'on',
#  'its',
#  'platform',
#  'in',
#  'the',
#  'wake',
#  'of',
#  'his',
#  'controversial',
#  'comments',
#  'on',
#  'ongoing',
#  'protests',
#  'across',
#  'the',
#  'US',
#  ',',
#  'the',
#  'company',
#  'announced',
#  'Wednesday',
#  '.',
#  "'We",
#  'are',
#  'not',
#  'currently',
#  'promoting',
#  'the',
#  'President',
#  "'s",
#  'content',
#  'on',
#  'Snapchat',
#  "'s",
#  'Discover',
#  'platform',
#  '.',
#  'We',
#  'will',
#  'not',
#  'amplify',
#  'voices',
#  'who',
#  'incite',
#  'racial',
#  'violence',
#  'and',
#  'injustice',
#  'by',
#  'giving',
#  'them',
#  'free',
#  'promotion',
#  'on',
#  'Discover',
#  "'",
#  ',',
#  'Rachel',
#  'Racusen',
#  ',',
#  'a',
#  'spokesperson',
#  'for',
#  'Snap',
#  ',',
#  'Snapchat',
#  "'s",
#  'parent',
#  'company',
#  ',',
#  'said',
#  'in',
#  'a',
#  'statement',
# ...

# %%
freq = nltk.FreqDist(word_tk)

print(freq.most_common())
# Out:
# [(',', 5), ("'s", 4), ('on', 4), ('the', 4), ('Snapchat', 3), ('.', 3), ('will', 2), ('President', 2), ('platform', 2), ('in', 2), ('company', 2), ('Wednesday', 2), ('not', 2), ('Discover', 2), ('a', 2), ('no', 1), ('longer', 1), ('promote', 1), ('Donald', 1), ('Trump', 1), ('account', 1), ('its', 1), ('wake', 1), ('of', 1), ('his', 1), ('controversial', 1), ('comments', 1), ('ongoing', 1), ('protests', 1), ('across', 1), ('US', 1), ('announced', 1), ("'We", 1), ('are', 1), ('currently', 1), ('promoting', 1), ('content', 1), ('We', 1), ('amplify', 1), ('voices', 1), ('who', 1), ('incite', 1), ('racial', 1), ('violence', 1), ('and', 1), ('injustice', 1), ('by', 1), ('giving', 1), ('them', 1), ('free', 1), ('promotion', 1), ("'", 1), ('Rachel', 1), ('Racusen', 1), ('spokesperson', 1), ('for', 1), ('Snap', 1), ('parent', 1), ('said', 1), ('statement', 1)]

# %%
freq.plot(20)

# %%
Tech_news_clean = [word for word in word_tk if word.isalpha()]
print(Tech_news_clean[:100])
# Out:
# ['Snapchat', 'will', 'no', 'longer', 'promote', 'President', 'Donald', 'Trump', 'account', 'on', 'its', 'platform', 'in', 'the', 'wake', 'of', 'his', 'controversial', 'comments', 'on', 'ongoing', 'protests', 'across', 'the', 'US', 'the', 'company', 'announced', 'Wednesday', 'are', 'not', 'currently', 'promoting', 'the', 'President', 'content', 'on', 'Snapchat', 'Discover', 'platform', 'We', 'will', 'not', 'amplify', 'voices', 'who', 'incite', 'racial', 'violence', 'and', 'injustice', 'by', 'giving', 'them', 'free', 'promotion', 'on', 'Discover', 'Rachel', 'Racusen', 'a', 'spokesperson', 'for', 'Snap', 'Snapchat', 'parent', 'company', 'said', 'in', 'a', 'statement', 'Wednesday']

# %%
Tech_news_clean = [w.lower() for w in Tech_news_clean]
print(Tech_news_clean)
# Out:
# ['snapchat', 'will', 'no', 'longer', 'promote', 'president', 'donald', 'trump', 'account', 'on', 'its', 'platform', 'in', 'the', 'wake', 'of', 'his', 'controversial', 'comments', 'on', 'ongoing', 'protests', 'across', 'the', 'us', 'the', 'company', 'announced', 'wednesday', 'are', 'not', 'currently', 'promoting', 'the', 'president', 'content', 'on', 'snapchat', 'discover', 'platform', 'we', 'will', 'not', 'amplify', 'voices', 'who', 'incite', 'racial', 'violence', 'and', 'injustice', 'by', 'giving', 'them', 'free', 'promotion', 'on', 'discover', 'rachel', 'racusen', 'a', 'spokesperson', 'for', 'snap', 'snapchat', 'parent', 'company', 'said', 'in', 'a', 'statement', 'wednesday']

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
Tech_news_clean = [w for w in Tech_news_clean if not w in stop_words]
print(Tech_news_clean)
# Out:
# ['snapchat', 'longer', 'promote', 'president', 'donald', 'trump', 'account', 'platform', 'wake', 'controversial', 'comments', 'ongoing', 'protests', 'across', 'us', 'company', 'announced', 'wednesday', 'currently', 'promoting', 'president', 'content', 'snapchat', 'discover', 'platform', 'amplify', 'voices', 'incite', 'racial', 'violence', 'injustice', 'giving', 'free', 'promotion', 'discover', 'rachel', 'racusen', 'spokesperson', 'snap', 'snapchat', 'parent', 'company', 'said', 'statement', 'wednesday']

# %%
Tech_news_clean_2 = "snapchat longer promote president donald trump account platform wake controversial comments ongoing protests across us company announced wednesday currently promoting president content snapchat discover platform amplify voices incite racial violence injustice giving free promotion discover rachel racusen spokesperson snap snapchat parent company said statement wednesday"

# %%
word_tk2 = word_tokenize(Tech_news_clean_2)
word_tk2
# Out:
# ['snapchat',
#  'longer',
#  'promote',
#  'president',
#  'donald',
#  'trump',
#  'account',
#  'platform',
#  'wake',
#  'controversial',
#  'comments',
#  'ongoing',
#  'protests',
#  'across',
#  'us',
#  'company',
#  'announced',
#  'wednesday',
#  'currently',
#  'promoting',
#  'president',
#  'content',
#  'snapchat',
#  'discover',
#  'platform',
#  'amplify',
#  'voices',
#  'incite',
#  'racial',
#  'violence',
#  'injustice',
#  'giving',
#  'free',
#  'promotion',
#  'discover',
#  'rachel',
#  'racusen',
#  'spokesperson',
#  'snap',
#  'snapchat',
#  'parent',
#  'company',
#  'said',
#  'statement',
#  'wednesday']

# %%
freq2 = nltk.FreqDist(word_tk2)

print(freq2.most_common())
# Out:
# [('snapchat', 3), ('president', 2), ('platform', 2), ('company', 2), ('wednesday', 2), ('discover', 2), ('longer', 1), ('promote', 1), ('donald', 1), ('trump', 1), ('account', 1), ('wake', 1), ('controversial', 1), ('comments', 1), ('ongoing', 1), ('protests', 1), ('across', 1), ('us', 1), ('announced', 1), ('currently', 1), ('promoting', 1), ('content', 1), ('amplify', 1), ('voices', 1), ('incite', 1), ('racial', 1), ('violence', 1), ('injustice', 1), ('giving', 1), ('free', 1), ('promotion', 1), ('rachel', 1), ('racusen', 1), ('spokesperson', 1), ('snap', 1), ('parent', 1), ('said', 1), ('statement', 1)]

# %%
freq2.plot(10)

# %%
from nltk.stem import PorterStemmer

porter = PorterStemmer()

# %%
porter.stem(Tech_news_clean_2)
# Out:
# 'snapchat longer promote president donald trump account platform wake controversial comments ongoing protests across us company announced wednesday currently promoting president content snapchat discover platform amplify voices incite racial violence injustice giving free promotion discover rachel racusen spokesperson snap snapchat parent company said statement wednesday'

# %%
Tech_news_clean_3 = "snapchat longer promote president donald trump account platform wake controversial comments ongoing protests across us company announced wednesday currently promoting president content snapchat discover platform amplify voices incite racial violence injustice giving free promotion discover rachel racusen spokesperson snap snapchat parent company said statement wednesday"

# %%
word_tk3 = word_tokenize(Tech_news_clean_3)
word_tk3
# Out:
# ['snapchat',
#  'longer',
#  'promote',
#  'president',
#  'donald',
#  'trump',
#  'account',
#  'platform',
#  'wake',
#  'controversial',
#  'comments',
#  'ongoing',
#  'protests',
#  'across',
#  'us',
#  'company',
#  'announced',
#  'wednesday',
#  'currently',
#  'promoting',
#  'president',
#  'content',
#  'snapchat',
#  'discover',
#  'platform',
#  'amplify',
#  'voices',
#  'incite',
#  'racial',
#  'violence',
#  'injustice',
#  'giving',
#  'free',
#  'promotion',
#  'discover',
#  'rachel',
#  'racusen',
#  'spokesperson',
#  'snap',
#  'snapchat',
#  'parent',
#  'company',
#  'said',
#  'statement',
#  'wednesday']

# %%
freq3 = nltk.FreqDist(word_tk3)

print(freq3.most_common())
# Out:
# [('snapchat', 3), ('president', 2), ('platform', 2), ('company', 2), ('wednesday', 2), ('discover', 2), ('longer', 1), ('promote', 1), ('donald', 1), ('trump', 1), ('account', 1), ('wake', 1), ('controversial', 1), ('comments', 1), ('ongoing', 1), ('protests', 1), ('across', 1), ('us', 1), ('announced', 1), ('currently', 1), ('promoting', 1), ('content', 1), ('amplify', 1), ('voices', 1), ('incite', 1), ('racial', 1), ('violence', 1), ('injustice', 1), ('giving', 1), ('free', 1), ('promotion', 1), ('rachel', 1), ('racusen', 1), ('spokesperson', 1), ('snap', 1), ('parent', 1), ('said', 1), ('statement', 1)]

# %%
freq3.plot(10)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
word_cloud = WordCloud().generate(Tech_news_clean_3)

# %%
plt.imshow(word_cloud)
